# %% [markdown]
# <a href="https://colab.research.google.com/github/KUNALKODARLIKAR/Hotel_booking_analysis/blob/main/Kunal_Kodarlikar_Hotel_Booking_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This dataset can help you explore those questions!
#
# ## <b>This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. </b>
#
# ## <b> Explore and analyze the data to discover important factors that govern the bookings. </b>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pd.set_option("display.max_columns", 36)
plt.style.use('seaborn')


plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titlesize"] = 25
plt.rcParams["axes.titleweight"] = 'bold'
plt.rcParams['xtick.labelsize']=10
plt.rcParams['ytick.labelsize']=10
plt.rcParams["axes.labelsize"] = 15
plt.rcParams["legend.fontsize"] = 15
plt.rcParams["legend.title_fontsize"] = 15

# %% [markdown]
# **Mounting drive**

# %%
from google.colab import drive     
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **CSV File Location**

# %%
file_path="/content/Hotel Bookings Analysis-Kunal Kodarlikar.csv"

# %% [markdown]
# Reading Data

# %%
df= pd.read_csv(file_path)

# %% [markdown]
# **Data Exploration**

# %%
print(f' We have total {df.shape[0]} rows and {df.shape[1]} columns.')
# Out:
#  We have total 119390 rows and 32 columns.

# %%
df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
df.tail(5)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
#looking at the min, max ,mean values etc. NAN values for mean,25% ,50%,75%,max indicates those are categorical columns.
df.describe(include='all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %%
#looking for the data types non null entries
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# **Data Description**:
#
# 0. hotel : Hotel(Resort Hotel or City Hotel)
#
# 1.	is_canceled : Value indicating if the booking was canceled (1) or not ()
#
# 2.	lead_time : Number of days that elapsed between the entering date of the booking into the PMS and the arrival date
#
# 3.	arrival_date_year : Year of arrival date
#
# 4.	arrival_date_month : Month of arrival date
#
# 5.	arrival_date_week_number : Week number of year for arrival date
#
# 6.	arrival_date_day_of_month : Day of arrival date
#
# 7.	stays_in_weekend_nights : Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
#
# 8.	stays_in_week_nights : Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
#
# 9.	adults : Number of adults
#
# 10.	children : Number of children
#
# 11.	babies : Number of babies
#
# 12.	meal : Type of meal booked. Categories are presented in standard hospitality
#
#   meal packages
#
# 13.	country : Country of origin
#
# 14.	market_segment : Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# 15.	distribution_channel : Booking distribution channel. The term “TA” means
#
#   “Travel Agents” and “TO” means “Tour Operators”
#
# 16.	is_repeated_guest : Value indicating if the booking name was from a repeated
#   guest (1) or not (0)
#
# 17.	previous_cancellations : Number of previous bookings that were cancelled by the customer prior to the current booking
#
# 18.	previous_bookings_not_canceled : Number of previous bookings not cancelled by
#  the customer prior to the current booking
#
# 19.	reserved_room_type : Code of room type reserved. Code is presented instead of
#  designation for anonymity reasons
#
# 20.	assigned_room_type : Code for the type of room assigned to the booking
#
# 21.	booking_changes : Number of changes/amendments made to the booking from the
#    moment the booking was entered on the PMS until the moment of
#   check-in or cancellation
#
# 22.	deposit_type : Indication on if the customer made a deposit to guarantee the
#   booking
#
# 23.	agent : ID of the travel agency that made the booking
#
# 24.	company : ID of the company/entity that made the booking or responsible for
#  paying the booking.
#
# 25.	days_in_waiting_list : Number of days the booking was in the waiting list
#  before it was confirmed to the customer
#
# 26.	customer_type : Type of booking, assuming one of four categories
#
# 27.	adr : Average Daily Rate as defined by dividing the sum of all lodging
#  transactions by the total number of staying nights
#
# 28.	required_car_parking_spaces : Number of car parking spaces required by the
#  customer
#
# 29.	total_of_special_requests : Number of special requests made by the customer
#   (e.g. twin bed or high floor)
#
# 30.	reservation_status : Reservation last status, assuming one of three categories
# •	Canceled – booking was canceled by the customer
# •	Check-Out – customer has checked in but already departed
# •	No-Show – customer did not check-in and did inform the hotel of the reason why
# 31.	reservation_status_date : Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel.

# %%
# creating a copy of our dataset
hb=df.copy()

# %%
# columns name list
print(list(hb.columns))
# Out:
# ['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date']

# %%
# Converting Data Type object type to datetime
#hb['reservation_status_date'] = pd.to_datetime(hb['reservation_status_date'], format = '%Y-%m-%d')

# %% [markdown]
# **Data Cleaning**

# %%
# Finding the duplicate rows
hb.duplicated().value_counts()
 #True Means Duplicate Rows
 #False Means Non-Duplicate Rows
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
# Visulizing through Count pot
plt.figure(figsize=(10,10))
sns.countplot(x=hb.duplicated())

# %% [markdown]
# **So we have 31994 duplicate rows in our data. So we will drop the duplicate rows from our data.**

# %%
# Dropping the duplicate rows
hb= hb.drop_duplicates()

# %%
# Data set reduced
hb.shape
# Out:
# (87396, 32)

# %%
#Check For Null Values
hb.isna().sum().sort_values(ascending=False)[:6].reset_index().rename(columns={'index':'Columns',0:'Null values'})
# Out:
#               Columns  Null values
# 0             company        82137
# 1               agent        12193
# 2             country          452
# 3            children            4
# 4  reserved_room_type            0
# 5  assigned_room_type            0

# %% [markdown]
# **Visulaizing null values through Heatmap and Displot**

# %%
plt.figure(figsize=(10,6))
sns.displot(
    data=hb.isna().melt(value_name="missing"),
   y="variable",
    hue="missing",
    multiple="fill",
    aspect=1.25
)
plt.savefig("Places of missing values in column.png", dpi=100)

# %%
plt.figure(figsize=(25, 10))
sns.heatmap(hb.isnull(), cbar=False, yticklabels=False,cmap='viridis')
plt.xlabel("Name Of Columns")
plt.title("Places of missing values in column")
# Out:
# Text(0.5, 1.0, 'Places of missing values in column')

# %% [markdown]
# **Compare between Heatmap and Displot**,
#
# We Have Null values in columns- Company, agent, Country, Children.
#
# for company and agent I will fill the Missing values with 0
# for country I will fill Missing values with boject 'Others'. ( assuming while collecting data country was not found so user selected the 'Others' option.)
# AS the count of missing values in Children Column is only 4, so we can replace with 0 considering no childrens.

# %%
# Filling/replacing null values with 0.
null_columns=['agent','children','company']
for col in null_columns:
  hb[col].fillna(0,inplace=True)

# %%
# Replacing NA values with 'others'
hb['country'].fillna('others',inplace=True)

# %%
#Successfully handled  Null Values
hb.isna().sum().sort_values(ascending=False)[:6].reset_index().rename(columns={'index':'Columns',0:'Null values'})
# Out:
#                        Columns  Null values
# 0                        hotel            0
# 1                  is_canceled            0
# 2           reservation_status            0
# 3    total_of_special_requests            0
# 4  required_car_parking_spaces            0
# 5                          adr            0

# %%
# Checking the unique values in categorical columns.
categorical_cols=list(set(hb.drop(columns=['reservation_status_date','country','arrival_date_month']).columns)-set(hb.describe()))
for col in categorical_cols:
  print(f'Unique values in column {col} are:, {(hb[col].unique())}')
# Out:
# Unique values in column deposit_type are:, ['No Deposit' 'Refundable' 'Non Refund']
# Unique values in column reservation_status are:, ['Check-Out' 'Canceled' 'No-Show']
# Unique values in column distribution_channel are:, ['Direct' 'Corporate' 'TA/TO' 'Undefined' 'GDS']
# Unique values in column reserved_room_type are:, ['C' 'A' 'D' 'E' 'G' 'F' 'H' 'L' 'P' 'B']
# Unique values in column market_segment are:, ['Direct' 'Corporate' 'Online TA' 'Offline TA/TO' 'Complementary' 'Groups'
#  'Undefined' 'Aviation']
# Unique values in column assigned_room_type are:, ['C' 'A' 'D' 'E' 'G' 'F' 'I' 'B' 'H' 'P' 'L' 'K']
# Unique values in column meal are:, ['BB' 'FB' 'HB' 'SC' 'Undefined']
# Unique values in column customer_type are:, ['Transient' 'Contract' 'Transient-Party' 'Group']
# Unique values in column hotel are:, ['Resort Hotel' 'City Hotel']

# %%
# Modify some columns

hb['total_people'] = hb['adults'] + hb['babies'] + hb['children']   
hb['total_stay'] = hb['stays_in_weekend_nights'] + hb['stays_in_week_nights']

# %%
# droppping all 166 those rows in which addtion of of adlults ,children and babies is 0. 
# That simply means  no bookings were made.
len(hb[hb['adults']+hb['babies']+hb['children']==0])
hb.drop(hb[hb['adults']+hb['babies']+hb['children']==0].index,inplace=True)

# %%
# Checking the final rows and columns
hb.shape
# Out:
# (87230, 34)

# %% [markdown]
# **EDA (Exploratory Data Analysis)**

# %% [markdown]
# 1) **Which type of hotel is mostly preferred  by the guests**?

# %%
# Visualizsing the by pie chart.
hb['hotel'].value_counts().plot.pie(explode=[0.05, 0.05],autopct='%.0f%%', shadow=True, figsize=(7,5),fontsize=15)   
plt.title(' Most Preffered  Hotel')
# Out:
# Text(0.5, 1.0, ' Most Preffered  Hotel')

# %% [markdown]
# **Observation**:
#
# **City Hotel(61%) is most preffered hotel by guests. Thus city hotels has maximum bookings**.

# %% [markdown]
# 2) **What is the pecentage of cancellation?**

# %%
hb['is_canceled'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(7,5),fontsize=15)
plt.title("Cancellation and Non Cancellation")
# Out:
# Text(0.5, 1.0, 'Cancellation and Non Cancellation')

# %% [markdown]
# **Observation** :
#
# 0 % = Not cancelled
#
# 1 % = cancelled
#
# 27.5 % of the bookings were cancelled.

# %% [markdown]
# 3) What is the percentage distribution of required_car_parking_spaces?

# %%
hb['required_car_parking_spaces'].value_counts().plot.pie(explode=[0.05]*5, autopct='%1.1f%%',shadow=False,figsize=(12,8),fontsize=15,labels=None)

labels=hb['required_car_parking_spaces'].value_counts().index
plt.title('% Distribution of required car parking spaces')
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# **Observation**:
#
# 91.6 % guests did not required the parking space. only 8.3 % guests required only 1 parking space.

# %% [markdown]
# 4) **Which type of food is mostly preferred by the guests**?

# %%
# hb['meal'].value_counts().plot.pie(explode=[0.05, 0.05,0.05,0.05,0.05], autopct='%1.1f%%', shadow=True, figsize=(20,15),fontsize=20)
plt.figure(figsize=(18,8))
sns.countplot(x=hb['meal'])
plt.xlabel('Meal Type')
plt.ylabel('Count')
plt.title("Preferred Meal Type")
# Out:
# Text(0.5, 1.0, 'Preferred Meal Type')

# %% [markdown]
#  ### Observation ###
#
# Types of meal in hotels:
#
# BB - (Bed and Breakfast)
# HB- (Half Board)
# FB- (Full Board)
# SC- (Self Catering)
#
#
# So the most preferred meal type by the guests is BB( Bed and Breakfast) , HB- (Half Board) and SC- (Self Catering) are equally preferred.

# %% [markdown]
# 5) **Which Agent made the most bookings**?

# %%
# Return highest bookings made by agents
highest_bookings= hb.groupby(['agent'])['agent'].agg({'count'}).reset_index().rename(columns={'count': "Most_Bookings" }).sort_values(by='Most_Bookings',ascending=False)

 # As agent 0 was NAN value and we replaced it with 0 and indicates no bookings.so droping.
highest_bookings.drop(highest_bookings[highest_bookings['agent']==0].index,inplace=True) 

# Taking top 10 bookings made by agent
top_ten_highest_bookings=highest_bookings[:10]

top_ten_highest_bookings
# Out:
#      agent  Most_Bookings
# 9      9.0          28721
# 174  240.0          13028
# 14    14.0           3342
# 7      7.0           3294
# 183  250.0           2779
# 175  241.0           1644
# 27    28.0           1493
# 8      8.0           1383
# 1      1.0           1228
# 6      6.0           1117

# %%
#Visualizaing the Bar Graph

plt.figure(figsize=(18,8))
sns.barplot(x=top_ten_highest_bookings['agent'],y=top_ten_highest_bookings['Most_Bookings'],order=top_ten_highest_bookings['agent'])
plt.xlabel('Agent ID Number')
plt.ylabel('Number of Bookings')
plt.title("Most Bookings Made by the Agent")
# Out:
# Text(0.5, 1.0, 'Most Bookings Made by the Agent')

# %% [markdown]
# **Observation**:
#
# **Agent ID Number 9 made most of the bookings**

# %% [markdown]
# 6) **From which country the most guests are coming**?

# %%
# Counting the guests from various countries.
country_hb=hb['country'].value_counts().reset_index().rename(columns={'index': 'country','country': 'count of guests'})[:5]
# country_hb1=hb['country'].value_counts().reset_index().rename(columns={'index': 'country','country': 'count of guests'})

# Visualizing by  plotting the graph
plt.figure(figsize=(20,8))
sns.barplot(x=country_hb['country'],y=country_hb['count of guests'])
plt.xlabel('Country')
plt.ylabel('Number of guests',fontsize=12)
plt.title("Number of guests from diffrent Countries")
# Out:
# Text(0.5, 1.0, 'Number of guests from diffrent Countries')

# %%
#importing the folium library
import folium                                # searched on google 
import plotly.express as px

# %%
basemap = folium.Map()
guests_map = px.choropleth(country_hb, locations = country_hb['country'],color = country_hb['count of guests'], hover_name = country_hb['country'])
guests_map.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Observation**
#
# Most of the guests are coming from portugal i.e more 25000 guests
#
# Abbreevations for countries-
#
# 1.  PRT- Portugal
# 2.  GBR- United Kingdom
# 3.  FRA- France
# 4.  ESP- Spain
# 5.  DEU - Germany

# %% [markdown]
# 7) **Which year had the highest bookings**?

# %%
# Set plot size
plt.figure(figsize=(12,8))

#  Plot with countplot
sns.countplot(x=hb['arrival_date_year'],hue=hb['hotel'])
plt.title("Year Wise bookings")
# Out:
# Text(0.5, 1.0, 'Year Wise bookings')

# %% [markdown]
# **Observation**
# 1.	**2016 had the highest bookings**.
# 2.	**2015 had less  bookings**.
# 3.	**Overall City hotels had the most of the bookings**.

# %% [markdown]
# 8) **Which Hotel type has the highest ADR**?

# %%
# group by hotel
grup_by_hotel=hb.groupby('hotel')

# %%
#grouping by hotel adr
highest_adr=grup_by_hotel['adr'].mean().reset_index()

#set plot size
plt.figure(figsize=(10,8))

# set labels
plt.xlabel('Hotel type')
plt.ylabel('ADR')
plt.title("Avg ADR of each Hotel type")

#plot the graph
sns.barplot(x=highest_adr['hotel'],y=highest_adr['adr'])

# %% [markdown]
# **Observation**
#
# •	**City hotel has the highest ADR**.
#
# •	**That means city hotels are generating more revenues than the resort hotels**.
#
# •	**More the ADR more is the revenue**.

# %% [markdown]
# 9) **ADR across different market segment**?

# %%
Grupby=hb.groupby(['market_segment','hotel','is_canceled'])['adr'].mean().reset_index()   # group by

# set plot size and plto barchart
plt.figure(figsize=(18,6))
sns.barplot(x='market_segment',y='adr',hue='hotel',data=Grupby.sort_values(by='adr',ascending=False))
plt.title('Adr across market segment')
# Out:
# Text(0.5, 1.0, 'Adr across market segment')

# %% [markdown]
# **Obseravtion**
#
# •	**'Direct' and 'Online TA' are contributing the most in both types of hotels**.
#
# •	**Aviation segment should focus on increasing the bookings of 'City Hotel'**

# %% [markdown]
# 10) **Correlation of the columns**?

# %%
plt.figure(figsize=(18,10))
sns.heatmap(hb.corr(),annot=True)
plt.title('Co-relation of the columns')
# Out:
# Text(0.5, 1.0, 'Co-relation of the columns')

# %% [markdown]
# 1) Lead_time and Total_stay is positively corelated.
# That means more is the stay of cutsomer more will be the lead time.
#
# 2)Adults,childrens and babies are corelated to each other.
# That means more the people more will be adr.

# %% [markdown]
# 11) ADR across the different month.

# %%
#groupby
bookings_by_months=hb.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index()

#create month list
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# it will take the order of the month list in the df along with values
bookings_by_months['arrival_date_month']=pd.Categorical(bookings_by_months['arrival_date_month'],categories=months,ordered=True)

#sortting
bookings_by_months=bookings_by_months.sort_values('arrival_date_month')

bookings_by_months
# Out:
#    arrival_date_month         hotel         adr
# 8             January    City Hotel   85.269875
# 9             January  Resort Hotel   49.181693
# 6            February    City Hotel   89.266427
# 7            February  Resort Hotel   54.102809
# 15              March  Resort Hotel   57.590889
# 14              March    City Hotel   95.193911
# 0               April    City Hotel  117.314134
# 1               April  Resort Hotel   79.283805
# 17                May  Resort Hotel   80.551101
# 16                May    City Hotel  128.055724
# 13               June  Resort Hotel  112.380859
# 12               June    City Hotel  123.996416
# 11               July  Resort Hotel  156.166914
# 10               July    City Hotel  120.318314
# 3              August  Resort Hotel  187.566659
# 2              August    City Hotel  125.148662
# 22          September    City Hotel  118.764693
# 23          September  Resort Hotel  100.892331
# 20            October    City Hotel  107.585401
# ...

# %%
# set plot size and plot the line
plt.figure(figsize=(20,8))
sns.lineplot(x=bookings_by_months['arrival_date_month'],y=bookings_by_months['adr'],hue=bookings_by_months['hotel'])

# set lables
plt.title('ADR across each month')
plt.xlabel('Month')
plt.ylabel('ADR')
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# **Observation**
#
# For Resrot hotel is ADR is high in the months June,July,August as compared to City Hotels. May be Customers/People wants to spend their Summer vaccation in Resorts Hotels.
#
# The best time for guests to visit Resort or City hotels is January, February, March, April,October, November and December as the avrage daily rate in this month is very low.

# %% [markdown]
# 12) What is the Optimal stay length in both types of hotels ?

# %%
stay = hb.groupby(['total_stay', 'hotel']).agg('count').reset_index()   # group by total stay and hotel
stay = stay.iloc[:, :3]                                                   # take 1st 3 columns
stay = stay.rename(columns={'is_canceled':'Number of stays'})    # rename the columns

# %%
# set plot size and plot barchart
plt.figure(figsize=(18,9))
sns.barplot(x='total_stay',y='Number of stays',hue='hotel',data=stay)

#set labels
plt.title('Optimal Stay Length in Both hotel types')
plt.ylabel('count of stays')
plt.xlabel('total_stay(days)')
# Out:
# Text(0.5, 0, 'total_stay(days)')

# %% [markdown]
# **Observation**:
#
# Optimal stay in both the type hotel is less than 7 days.

# %% [markdown]
# **Conclusions**:

# %% [markdown]
# 1.	City hotels are the most preferred hotel type by the guests. We can say City hotel is the busiest hotel.
#
# 2.	27.5 % bookings were got cancelled out of all the bookings.
#
# 3.	Maximum number of guests were from Portugal, i.e. more than 25000 guests.
#
# 4. So the most preferred meal type by the guests is BB( Bed and Breakfast) And HB- (Half Board) and SC- (Self Catering) are equally preferred.
#
# 5.	Most of the bookings for City hotels and Resort hotel were happened in 2016.
#
# 6.  Aviation segment should focus on increasing the bookings of 'City Hotel
#
# 7.  91.6 % guests did not required the parking space. only 8.3 % guests required only 1 parking space.
#
# 8.  Optimal stay in city & Resort the type hotel is less than 7 days.
#
# 9. For Resrot hotel is ADR is high in the months June,July,August as compared   to City Hotels. May be Customers/People wants to spend their Summer vaccation in Resorts Hotels. The best time for guests to visit Resort or City hotels is January, February, March, April,October, November and December as the avrage daily rate in this month is very low.
